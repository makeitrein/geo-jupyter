# %% [markdown]
# ## Loading SQL and testing

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://jordanrein:fart@localhost/geo

# %%
# %sql SELECT * FROM triples LIMIT 5;
# Out:
#  * postgresql://jordanrein:***@localhost/geo
# 5 rows affected.
# [('6e366339-0881-4d66-a173-c3813beabe30', 'f793acaf-e574-488f-90d0-106d4c07e521', 'name', 'ff199575-e530-4ba5-b757-524b9a62dc0b', 'string', '0xe3d08763498e3247ec00a481f199b018f2148723', False, False, None, None, 'The pain system is subject to perceptual influences.', None),
#  ('89d4b9b1-bfb1-4867-9493-9915caaa4dbf', 'f793acaf-e574-488f-90d0-106d4c07e521', 'a1cc9e04-11a9-4968-83e8-c716f3b3de3b', 'dffb5a2a-74b2-4c60-8e7c-7a37159d2807', 'entity', '0xe3d08763498e3247ec00a481f199b018f2148723', False, False, None, None, None, 'dffb5a2a-74b2-4c60-8e7c-7a37159d2807'),
#  ('12485d9a-9bd9-49dd-9c2f-91d7d95d4681', 'f793acaf-e574-488f-90d0-106d4c07e521', '278cd727-0ba2-4c15-a683-1d0f78c83fdd', '2c4cfba8-751f-4737-bdc5-8d37b0474465', 'entity', '0xe3d08763498e3247ec00a481f199b018f2148723', False, False, None, None, None, '2c4cfba8-751f-4737-bdc5-8d37b0474465'),
#  ('bf5da0e6-1ac0-45c2-b059-096ba54c2bc4', 'f793acaf-e574-488f-90d0-106d4c07e521', '03e16cf8-6d6c-4a69-ba03-32e3d15a1a5a', '3a52b411-f4b1-4639-8ef5-32b382218642', 'string', '0xe3d08763498e3247ec00a481f199b018f2148723', False, False, None, None, '2021-03-04', None),
#  ('66991f0d-e1c3-48b0-a4d2-d3f272fdedc0', 'f793acaf-e574-488f-90d0-106d4c07e521', 'type', 'bbeb8aea-b070-4408-9ed6-9eaa2fa02547', 'entity', '0xe3d08763498e3247ec00a481f199b018f2148723', False, False, None, None, None, 'bbeb8aea-b070-4408-9ed6-9eaa2fa02547')]

# %% [markdown]
# ---
# ## Defining Python Graphql Helpers

# %%
import requests
import json

def run_graphql(query):
    url = "http://localhost:5000/graphql"
    response = requests.post(url, json={'query': query}, headers=None)
    if response.status_code == 200:
        result = json.loads(response.content)
        return print(json.dumps(result, indent=2))
    else:
        result = response.content
        return print(result)

# %% [markdown]
# ---
# ## Basic "types" + "schema" computed columns

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION entities_types(e_row entities)
# RETURNS SETOF entities AS $$
# BEGIN
#     RETURN QUERY
#     SELECT e.*
#     FROM entities e
#     WHERE e.id IN (
#         SELECT t.value_id
#         FROM triples t
#         WHERE t.entity_id = e_row.id AND t.attribute_id = 'type'
#     );
# END;
# $$ LANGUAGE plpgsql STRICT STABLE;
#
# CREATE OR REPLACE FUNCTION entities_schema_definition(e_row entities)
# RETURNS SETOF entities AS $$
# BEGIN
#   RETURN QUERY
#   SELECT e.*
#         FROM entities e
#         WHERE e.id IN (
#             SELECT t.value_id
#             FROM triples t
#             WHERE t.entity_id = e_row.id
#             AND t.attribute_id = '01412f83-8189-4ab1-8365-65c7fd358cc1'
#         );
# END;
# $$ LANGUAGE plpgsql STRICT STABLE;
#
# CREATE OR REPLACE FUNCTION entities_schema(e_row entities)
# RETURNS SETOF entities AS $$
# BEGIN
#     -- Using CTE to first fetch all types of the given entity
#     RETURN QUERY
#     WITH entity_types AS (
#         SELECT t.value_id AS type_id
#         FROM triples t
#         WHERE t.entity_id = e_row.id AND t.attribute_id = 'type'
#     ),
#     type_attributes AS (
#         -- For each type, fetch the associated attributes
#         SELECT DISTINCT t.value_id AS attribute_id
#         FROM entity_types et
#         JOIN triples t ON t.entity_id = et.type_id AND t.attribute_id = '01412f83-8189-4ab1-8365-65c7fd358cc1'
#     )
#     SELECT e.*
#     FROM entities e
#     JOIN type_attributes ta ON e.id = ta.attribute_id;
# END;
# $$ LANGUAGE plpgsql STRICT STABLE;
# Out:
#  * postgresql://jordanrein:***@localhost/geo
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ## V2 "schema" computed columns

# %%
# %%sql
# DROP TYPE IF EXISTS Schema;
# CREATE TYPE Schema AS (
#     id text,
#     name text,
#     valueType text
# );
#
#
# CREATE OR REPLACE FUNCTION entities_schema(e_row entities)
# RETURNS SETOF entities AS $$
# BEGIN
#     -- Using CTE to first fetch all types of the given entity
#     RETURN QUERY
#     WITH entity_types AS (
#         SELECT t.value_id AS type_id
#         FROM triples t
#         WHERE t.entity_id = e_row.id AND t.attribute_id = 'type'
#     ),
#     type_attributes AS (
#         -- For each type, fetch the associated attributes
#         SELECT DISTINCT t.value_id AS attribute_id
#         FROM entity_types et
#         JOIN triples t ON t.entity_id = et.type_id AND t.attribute_id = '01412f83-8189-4ab1-8365-65c7fd358cc1'
#     )
#     SELECT e.*
#     FROM entities e
#     JOIN type_attributes ta ON e.id = ta.attribute_id;
# END;
# $$ LANGUAGE plpgsql STRICT STABLE;

# %% [markdown]
# ---
# ## Adding allSchemaTypes Query

# %%
query = """
{
 allEntities(first: 1) {
  nodes {
    id
    name
    schema {
        nodes {
        name
        valueType
    }
    }
    types {
     nodes {
       name
     }
    }
  }
}
}
"""

run_graphql(query)
# Out:
# {
#   "data": {
#     "allEntities": {
#       "nodes": [
#         {
#           "id": "000050f5-2674-453c-a087-46f1a6b2aab4",
#           "name": "An appreciation for ",
#           "schema": {
#             "nodes": [
#               {
#                 "name": "Markdown Content",
#                 "valueType": "9edb6fcc-e454-4aa5-8611-39d7f024c010"
#               }
#             ]
#           },
#           "types": {
#             "nodes": [
#               {
#                 "name": "Text Block"
#               }
#             ]
#           }
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# ---
# ## Adding allSchemaTypes Query

# %%
# %%sql
# CREATE OR REPLACE FUNCTION all_schema_types()
# RETURNS SETOF entities AS $$
# BEGIN
#   RETURN QUERY
#   SELECT e.*
#         FROM entities e
#         WHERE e.id IN (
#             SELECT t.entity_id
#             FROM triples t
#             WHERE t.attribute_id = 'type' AND t.value_id = 'd7ab4092-0ab5-441e-88c3-5c27952de773'
#         );
# END;
# $$ LANGUAGE plpgsql STRICT STABLE;
# Out:
#  * postgresql://jordanrein:***@localhost/geo
# Done.
# []

# %%
query = """
{
 allSchemaTypes(offset:2, first: 1) {
  nodes {
    id
    name
  
    schemaDefinition {
        nodes {
        id
        name
        valueType
        
        }
    }
  }
}
}
"""

run_graphql(query)
# Out:
# {
#   "data": {
#     "allSchemaTypes": {
#       "nodes": [
#         {
#           "id": "2dbcd90f-78aa-46f8-81f9-647b2aeee12b",
#           "name": "Organization",
#           "schemaDefinition": {
#             "nodes": [
#               {
#                 "id": "14611456-b466-4cab-920d-2245f59ce828",
#                 "name": "Relation",
#                 "valueType": null
#               },
#               {
#                 "id": "71a5569e-688e-4e0f-8eb0-d8c361211e7c",
#                 "name": "Twitter",
#                 "valueType": "9edb6fcc-e454-4aa5-8611-39d7f024c010"
#               },
#               {
#                 "id": "235ba0e8-dc7e-4bdd-a1e1-6d0d4497f133",
#                 "name": "Avatar",
#                 "valueType": "9edb6fcc-e454-4aa5-8611-39d7f024c010"
#               },
#               {
#                 "id": "e8010874-d330-4a4d-9907-62e89a19371a",
#                 "name": "Web URL",
#                 "valueType": "9edb6fcc-e454-4aa5-8611-39d7f024c010"
#               },
#               {
#                 "id": "f724b805-89e1-424b-b149-acff9ecfd0f7",
#                 "name": "Website",
#                 "valueType": "9edb6fcc-e454-4aa5-8611-39d7f024c010"
#               },
#               {
#                 "id": "a8d8509b-43be-4d07-b955-d8d5dcd22581",
#                 "name": "Mission",
#                 "valueType": "9edb6fcc-e454-4aa5-8611-39d7f024c010"
#               }
#             ]
#           }
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# ---
# ## Adding typeInfo

# %%
# %%sql
# CREATE OR REPLACE FUNCTION entities_with_type(type_id text default null)
# RETURNS SETOF entities AS $$
# BEGIN
#   RETURN QUERY
#   SELECT e.*
#         FROM entities e
#         WHERE e.id IN (
#             SELECT t.entity_id
#             FROM triples t
#             WHERE t.attribute_id = 'type'
#             AND (type_id IS NULL OR t.value_id = type_id)
#         );
# END;
# $$ LANGUAGE plpgsql STABLE;
# Out:
#  * postgresql://jordanrein:***@localhost/geo
# Done.
# []

# %%
query = """
{
 entitiesWithType(first: 1) {
  nodes {
    id
    name
    schema {
    nodes {
    name 
    valueType
    }
    }
  }
}
}
"""

run_graphql(query)
# Out:
# {
#   "data": {
#     "entitiesWithType": {
#       "nodes": [
#         {
#           "id": "3ad4df27-132f-4ef6-87f8-070f063b074c",
#           "name": "San Francisco",
#           "schema": {
#             "nodes": [
#               {
#                 "name": "Image",
#                 "valueType": "9edb6fcc-e454-4aa5-8611-39d7f024c010"
#               },
#               {
#                 "name": "Indexed Space Address",
#                 "valueType": "9edb6fcc-e454-4aa5-8611-39d7f024c010"
#               }
#             ]
#           }
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# ## Adding Computed Columns to Entities table

# %%
# %%sql
# DROP TYPE IF EXISTS EntityAttribute CASCADE;
# CREATE TYPE EntityAttribute AS (
#     type text,
#     value entities
# );
#
#
# DROP TYPE IF EXISTS PrimitiveAttribute CASCADE;
# CREATE TYPE PrimitiveAttribute AS (
#     id text,
#     type text,
#     value text
# );
# Out:
#  * postgresql://jordanrein:***@localhost/geo
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# CREATE OR REPLACE FUNCTION entities_opposing_arguments(e_row entities)
# RETURNS SETOF EntityAttribute AS $$
# BEGIN
#   RETURN QUERY
#   SELECT 'entity' AS type, e AS value
#         FROM entities e
#         WHERE e.id IN (
#             SELECT t.value_id
#             FROM triples t
#             WHERE t.entity_id = e_row.id
#             AND t.attribute_id = '0c0a2a95-1928-4ec4-876d-cc04075b7927'
#         );
# END;
# $$ LANGUAGE plpgsql STRICT STABLE;
# Out:
#  * postgresql://jordanrein:***@localhost/geo
# Done.
# []

# %% [markdown]
# ## Random Query

# %%
query = """
{
 allEntities(first: 100) {
    totalCount
   nodes {
   opposingArguments {
    nodes {
    type
    }
    }
   }
  }
}
"""

run_graphql(query)
# Out:
# {
#   "data": {
#     "allEntities": {
#       "totalCount": 104563,
#       "nodes": [
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         },
#         {
#           "opposingArguments": {
#             "nodes": []
#           }
#         }
#       ]
#     }
#   }
# }
